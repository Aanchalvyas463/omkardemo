# %%
print("Helllo Everyone!!")
# Out:
# Helllo Everyone!!

# %% [markdown]
# -variable = Whose values are vary time to time

# %%
_600= 100
name= "aanchal"
abc_123= 567.27

# %% [markdown]
# Variable and constant

# %% [markdown]
# ##################  Basics  ########################
# 1) Basic syntax
# 2) Variables
# 3) python packages information
# 4) Basic python code
# 5) Conditional statements
# 6) functions
# 7) loop
#
# ###################  Level 2  ##################
# 1) Strings
# 2) List
# 3) dictionary
# 4) tuples ==== write up
# 5) sets
# 6) file handling sessions
#
# ##################  Level 3  ####################
# 1) OOPS concept in python
# 2) how to create your own package
# 3) FLASK apps

# %% [markdown]
# ########### data types  ##############
# -integer                      int
# -float                        float
# -string                       str
# -boolean                      bool
# -complex conjugate            complex
#
# #use "$h$" sign on both side to make text italic
# $hiiiieeeee$

# %%
#to know the type of variable
num=100
type(num)
# Out:
# int

# %%
#to import a package and to get names of all the methods avail in that package

import random
dir(random)      #using dir we get the list of all the methods
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
#TO check the feature of method of any package

help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,100)  # generate any value randomly between 1 to 100
# Out:
# 78

# %%
import random
dir(random)
help(random.randint)
random.randint(1,100)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 69

# %%
import math

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
help(math.pi)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating-point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
# ...

# %%
math.pi
# Out:
# 3.141592653589793

# %%
print(math.sin(90))
print(math.sin(30))
# Out:
# 0.8939966636005579
# -0.9880316240928618

# %% [markdown]
# # to see the list of all packages .. go to cmd and write
# pip freeze

# %% [markdown]
# use esc+m to direct markdown the cell

# %% [markdown]
# #For EDA : exporatory data analysis
# -Numpy (numerical python)
# -pandas (database reaad and write operation)
# -matplotlib (plotting)
# -seaborn (plotting)
# -bokhe (plotting)
#
# #for Machine Learning:
# -sickit-learn (sklearn) (python) used by Data scientist
# -MLlib             (pyspark) used by data engineers
#
# #Deep learning applications:
# -tensorflow  (invented by google)
# -keras
# -pytorch
# -opencv
#
#
# #NLP
# -nltk (natural language tool kit)
# -scipy
#
# #BERT model
# -transformers
#
# #azure ml packages
# #chat gpt packages
# #open CV (computer vision)
# #flask
# #streamlit
# random
# math
# time
#
# DL+NLP == AI applications

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.6 MB 1.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/12.6 MB 2.3 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.6 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.6 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.6 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/12.6 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.6 MB 2.0 MB/s eta 0:00:05
#    -------------- ------------------------- 4.5/12.6 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.6 MB 2.3 MB/s eta 0:00:04
# ...

# %%
import numpy as np
dir(numpy)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_get_promotion_state',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_no_nep50_warning',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_set_promotion_state',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
# ...

# %%
help(numpy.sqrt)
# Out:
# Help on ufunc:
#
# sqrt = <ufunc 'sqrt'>
#     sqrt(x, /, out=None, *, where=True, casting='same_kind', order='K', dtype=None, subok=True[, signature])
#
#     Return the non-negative square-root of an array, element-wise.
#
#     Parameters
#     ----------
#     x : array_like
#         The values whose square-roots are required.
#     out : ndarray, None, or tuple of ndarray and None, optional
#         A location into which the result is stored. If provided, it must have
#         a shape that the inputs broadcast to. If not provided or None,
#         a freshly-allocated array is returned. A tuple (possible only as a
#         keyword argument) must have length equal to the number of outputs.
#     where : array_like, optional
#         This condition is broadcast over the input. At locations where the
#         condition is True, the `out` array will be set to the ufunc result.
#         Elsewhere, the `out` array will retain its original value.
# ...

# %%
np.sqrt(25)
# Out:
# np.float64(5.0)

# %%
np.square(9)
# Out:
# np.int64(81)

# %%
#to use method of any package directly 

from random import randint
randint(1,20)
# Out:
# 11

# %%
from math import sin,pi
print(sin(90))
print(pi)
# Out:
# 0.8939966636005579
# 3.141592653589793

# %% [markdown]
# # Python using 1#

# %% [markdown]
# ## Python min heading using 2#

# %% [markdown]
# # For bullet points use -
# - python is easy
# - I am a user.
# - We used to write code here
# - Hello Everyone

# %%
randint()   #using cursor inside brackets press shift+tab to get the info of method
math.sqrt()

# %% [markdown]
# - [1, 100]  === both 1 and 100 will include
# - [1,100) === 1 include and  100 will not include
# - (1,100] === 1 exclude and 100 will include
# - (1,100) === both 1 and 100 are excluded

# %%
import random
random

#o/p will show the location of the random package inside your laptop
# Out:
# <module 'random' from 'C:\\Users\\vyasa\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\random.py'>

# %%
import keyword

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 4.2 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/38.8 MB 2.3 MB/s eta 0:00:17
#    - -------------------------------------- 1.8/38.8 MB 2.6 MB/s eta 0:00:15
#    -- ------------------------------------- 2.1/38.8 MB 2.3 MB/s eta 0:00:17
#    -- ------------------------------------- 2.6/38.8 MB 2.3 MB/s eta 0:00:16
#    -- ------------------------------------- 2.9/38.8 MB 2.2 MB/s eta 0:00:17
#    -- ------------------------------------- 2.9/38.8 MB 2.2 MB/s eta 0:00:17
#    --- ------------------------------------ 3.1/38.8 MB 1.9 MB/s eta 0:00:20
#    --- ------------------------------------ 3.4/38.8 MB 1.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.2/38.8 MB 1.9 MB/s eta 0:00:19
# ...

# %%
import cv2
